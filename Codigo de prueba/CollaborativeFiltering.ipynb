# %%
import numpy as np
import pandas as pd
import ast
import kaggle
import os
pd.set_option('display.max_columns', None)

kaggle.api.authenticate()
kaggle.api.dataset_download_file('jvanelteren/boardgamegeek-reviews', 'games_detailed_info.csv', path = 'Escritorio\TFG\data')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jvanelteren/boardgamegeek-reviews
# True

# %%
juegos = pd.read_csv('../code/data/bgg-limpio-reviews.csv')
more_info = pd.read_csv('../code/data/games_detailed_info.csv')
more_info.drop_duplicates()
# Out:
# C:\Users\isaac\AppData\Local\Temp\ipykernel_9396\1826807688.py:2: DtypeWarning: Columns (29,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   more_info = pd.read_csv('../code/data/games_detailed_info.csv')
#        Unnamed: 0       type      id  \
# 0               0  boardgame   30549
# 1               1  boardgame     822
# 2               2  boardgame      13
# 3               3  boardgame   68448
# 4               4  boardgame   36218
# ...           ...        ...     ...
# 21626       21626  boardgame  296892
# 21627       21627  boardgame  217378
# 21628       21628  boardgame   18063
# 21629       21629  boardgame   10052
# 21630       21630  boardgame  165946
#
#                                                thumbnail  \
# 0      https://cf.geekdo-images.com/S3ybV1LAp-8SnHIXL...
# 1      https://cf.geekdo-images.com/okM0dq_bEXnbyQTOv...
# 2      https://cf.geekdo-images.com/W3Bsga_uLP9kO91gZ...
# ...

# %%
juegos = juegos.merge(more_info, on='id')
juegos.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9396\2023547764.py in ?()
# ----> 1 juegos = juegos.merge(more_info, on='id')
#       2 juegos.dropna(inplace=True)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ...
